# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-0e53350b-6050-49f7-a80a-4371f03738ee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e53350b-6050-49f7-a80a-4371f03738ee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import io
fivek_df = pd.read_csv(io.BytesIO(uploaded['five_k (1).csv']))

# %%
import pandas as pd
from sklearn.metrics import pairwise_distances
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, QuantileTransformer, PowerTransformer
from sklearn.metrics import pairwise_distances

# %%
fivek_df
# Out:
#       Unnamed: 0  \
# 0              0
# 1              1
# 2              2
# 3              3
# 4              4
# ...          ...
# 5230        5230
# 5231        5231
# 5232        5232
# 5233        5233
# 5234        5234
#
#      name                                                                                                                                                                               \
# 0     Se Eu Quiser Falar Com Deus                   ...
# 1     Saudade De Bahia                              ...
# 2     Canta Canta, Minha Gente                      ...
# 3     Mulher Eu Sei                                 ...
# 4     Rosa Morena                                   ...
# ...                                                 ...
# 5230  1812 Festival Overture, Op. 49: 1812 Overture,...
# 5231  Winter Fragments pour ensemble instrumental, s...
# 5232  Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3...
# ...

# %%
print(fivek_df.columns)
# Out:
# Index(['Unnamed: 0',
#        'name                                                                                                                                                                             ',
#        'artist                                          ', 'danceability ',
#        'energy   ', 'key ', 'loudness ', 'mode ', 'speechiness ',
#        'acousticness ', 'instrumentalness ', 'liveness ', 'valence ',
#        'tempo   ', 'type ', 'duration_ms ', 'time_signature ',
#        'id                     ', 'html'],
#       dtype='object')

# %%
fivek_df.head()
# Out:
#    Unnamed: 0  \
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#
#   name                                                                                                                                                                               \
# 0  Se Eu Quiser Falar Com Deus                   ...
# 1  Saudade De Bahia                              ...
# 2  Canta Canta, Minha Gente                      ...
# 3  Mulher Eu Sei                                 ...
# 4  Rosa Morena                                   ...
#
#    artist                                            danceability   energy     \
# 0  Gilberto Gil                                              0.658     0.2590
# 1  Antônio Carlos Jobim                                      0.742     0.3990
# 2  Martinho Da Vila                                          0.851     0.7300
# 3  Chico César                                               0.705     0.0502
# ...

# %%
fivek_df.rename(columns={'name                                                                                                                                                                             ': 'name'}, inplace=True)
fivek_df.rename(columns={'artist                                          ': 'artist'}, inplace=True)
fivek_df.rename(columns={'energy   ': 'energy'}, inplace=True)
fivek_df.rename(columns={'id                     ': 'id'}, inplace=True)

# %%
fivek_df.drop(columns=['time_signature ', 'html', 'type '], inplace=True)
fivek_df.drop(columns=['duration_ms '], inplace=True)

# %%
fivek_df.duplicated().value_counts()
fivek_df = fivek_df.drop_duplicates()

# %%
fivek_df.drop(columns=['Unnamed: 0', 'id'], inplace=True)

# %%
#separate namen und numerische werte for scaling
names_df = fivek_df[['name', 'artist']]
features_df = fivek_df.drop(columns=['name', 'artist'])

# %%
fivek_df
# Out:
#                                                    name  \
# 0     Se Eu Quiser Falar Com Deus                   ...
# 1     Saudade De Bahia                              ...
# 2     Canta Canta, Minha Gente                      ...
# 3     Mulher Eu Sei                                 ...
# 4     Rosa Morena                                   ...
# ...                                                 ...
# 5230  1812 Festival Overture, Op. 49: 1812 Overture,...
# 5231  Winter Fragments pour ensemble instrumental, s...
# 5232  Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3...
# 5233  Serenade For Strings In E, Op.22, B. 52: 1. Mo...
# 5234  Ravel: Boléro, M. 81                          ...
#
#                                                 artist  danceability   \
# 0     Gilberto Gil                                             0.6580
# 1     Antônio Carlos Jobim                                     0.7420
# 2     Martinho Da Vila                                         0.8510
# ...

# %%
methods = ["minmax", "standard", "robust", "quantile", "power"]
scalers = [MinMaxScaler(feature_range=(0, 1)), StandardScaler(), RobustScaler(), QuantileTransformer(n_quantiles=features_df.shape[0], output_distribution='uniform'), PowerTransformer()]
# MinMaxScaler not def
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-80c85c00eccd> in <cell line: 2>()
#       1 methods = ["minmax", "standard", "robust", "quantile", "power"]
# ----> 2 scalers = [MinMaxScaler(feature_range=(0, 1)), StandardScaler(), RobustScaler(), QuantileTransformer(n_quantiles=features_df.shape[0], output_distribution='uniform'), PowerTransformer()]
#
# NameError: name 'MinMaxScaler' is not defined

# %%
names_df.describe()
# Out:
#                                                      name  \
# count                                                5235
# unique                                               5011
# top     Scared to Be Lonely                           ...
# freq                                                    4
#
#                                                   artist
# count                                               5235
# unique                                              2176
# top     Death
# freq                                                  29
